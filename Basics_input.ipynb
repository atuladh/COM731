# %%
print("What is your name human?")
name = input()
print(f"It\'s nice to meet you human {name}!")
# Out:
# What is your name human?
# It's nice to meet you human Atul!

# %%
#Read in a user's name
name = input("What is your name human?")
print(f"It\'s nice to meet you human {name}!")
# Out:
# It's nice to meet you human Atul!

# %%
#Data Types
print("What is your name human?")
name = input()
print("How old are you?")
age = input()
print("How tall are you (in meteres)?")
height = input()
print("How much do you weigh (in kilograms)?")
weight = input()
bmi = float(weight)/((float(height))*(float(height)))
print(f"Your name is {name}, you are {age} years old, Your BMI is {bmi:.2f}.")
# Out:
# What is your name human?
# How old are you?
# How tall are you (in meteres)?
# How much do you weigh (in kilograms)?
# Your name is A, you are 30 years old, Your BMI is 28.08.
