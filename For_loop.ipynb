# %% [markdown]
# count_down

# %%
how_far = int(input("How far are we from the cave?"))

for steps in range(how_far, 0, -1):
    print(f"{steps} steps remaining")
print("We have reached the cave!")
# Out:
# 50 steps remaining
# 49 steps remaining
# 48 steps remaining
# 47 steps remaining
# 46 steps remaining
# 45 steps remaining
# 44 steps remaining
# 43 steps remaining
# 42 steps remaining
# 41 steps remaining
# 40 steps remaining
# 39 steps remaining
# 38 steps remaining
# 37 steps remaining
# 36 steps remaining
# 35 steps remaining
# 34 steps remaining
# 33 steps remaining
# 32 steps remaining
# 31 steps remaining
# 30 steps remaining
# 29 steps remaining
# 28 steps remaining
# 27 steps remaining
# 26 steps remaining
# 25 steps remaining
# 24 steps remaining
# 23 steps remaining
# 22 steps remaining
# 21 steps remaining
# 20 steps remaining
# 19 steps remaining
# 18 steps remaining
# 17 steps remaining
# 16 steps remaining
# 15 steps remaining
# 14 steps remaining
# 13 steps remaining
# 12 steps remaining
# 11 steps remaining
# 10 steps remaining
# 9 steps remaining
# 8 steps remaining
# 7 steps remaining
# 6 steps remaining
# 5 steps remaining
# 4 steps remaining
# ...
