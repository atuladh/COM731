# %% [markdown]
# # File Operations

# %% [markdown]
# ## Reference Books

# %% [markdown]
# - <font size="3">Fundametals of First Programs 2nd edition: Chapter 4</font>
# - <font size="3">Programming with Python: Module 11</font>
# - <font size="3">Starting out with Python: Chapter 6</font>
# - <font size="3">Intro to Python for Computer Science and Data Science: Chapter 9</font>

# %% [markdown]
# <font size="5">**Learning Objectives**</font><br>
# <font size="3">After this session, you should be able to:</font>
# - <font size="3">open and close a csv file</font>
# - <font size="3">identify the generic syntax and permissions to open a file for reading and writing a csv file</font>
# - <font size="3">read data from a file and write data to a csv file</font>

# %% [markdown]
# ***

# %% [markdown]
# # File Handling: csv

# %% [markdown]
# - <font size="3">In Python, we can use the module <span style="color: blue;">csv </span> to simplify file handling</font>
# - <font size="3">Designed to work out of the box with Excel-generated CSV files, it is easily adapted to work with a variety of CSV formats</font>
# - <font size="3">The csv library contains objects and other code to read, write, and process data from and to CSV files</font>

# %%
import csv

# %% [markdown]
# ## Open and Close a csv file
#
# - <font size="3">We use the built-in <span style="color: green;">open()</span> function and the keyword <span style="color: green;">with</span> and <span style="color: green;">as</span> in order to automatically close a file once we are done processing it</font>
# - <font size="3">The with statement simplifies exception handling by encapsulating common preparation and cleanup tasks.</font>
# - <font size="3"><b>Syntax:</b></font><br>
# &emsp;&emsp;&emsp;&emsp;<font size="3"> <span style="color: green;">with open</span>(file_name,mode,encoding='UTF-8') <span style="color: green;">as</span> file_object</font>:<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;#do something with the file<br>
# <div class="alert alert-block alert-info">
# <b>Note:</b> open() function creates a file object and associates it with a file on the disk</div><br>
# - <font size="3"><b>mode</b> is a character specifying how the file will be opened:</font>
#     - <font size="3"><b>read mode ("r")</b>: opens the specified file so contents can be retrieved; default</font>
#     - <font size="3"><b>write mode ("w")</b>: opens the specified file so that you can add data, starting at the beginning of the file (creates or overwrites the file)</font>
#     - <font size="3"><b>append mode ("a")</b>: opens the specified file so that you can add content to the end of a file that already contains data</font>
# - <font size="3"><b>encoding</b> is the process of translating characters into a format that can be stored and transmitted by a computer. In CSV files, encoding determines how the characters in the file are represented. UTF-8 and Latin-1 are two common encoding formats used in CSV files.</font>

# %%
# Import csv library
import csv

# define a file name
file_name = "people.csv"

# open a CSV file and display the successfully opened file's name
with open(file_name,encoding='UTF-8') as csv_file:
    print(f"{file_name} is now open for read")

# %% [markdown]
# ## File Error Handling
#
# <div class="alert alert-block alert-danger">
# <b>File Errors:</b> it is possible that when we attempt to open a file that an error occurs.  This may be due to an incorrect file path being specified, file does not exist, or access to the file being restricted <br>
#     <ul>
#     <li>We can use a <b>try...except</b> block to handle file errors.</li>
#         <ul>
#             <li>Syntax:</li>
#             <b>try:</b><br>
#             &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;statements<br>
#             <b>except exceptionName:</b><br>
#             &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;statements
#         </ul>
#     <li>The try part of the block will attempt to execute the relevant statements e.g. open a file for reading.</li>
#     <li>The except part of the block will deal with a particular error e.g. an IOError which occurs when a file cannot be accessed</li>
#     </ul>
# </div>

# %% [markdown]
# ### Example: File error when open a file

# %%
# Import csv library
import csv

# receive a filename or file path from a user: try to open movies.csv file
file_name = input("Enter a filename or file path: ")

# Open the file
with open(file_name,encoding='UTF-8') as csv_file:
    print(f"{file_name} is now open for read")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 file_name = input("Enter a filename or file path: ")
#       7 # Open the file
# ----> 8 with open(file_name,encoding='UTF-8') as csv_file:
#       9     print(f"{file_name} is now open for read")
#
# File /opt/anaconda3/envs/COM731/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'atl.csv'

# %% [markdown]
# ## File error handling using except

# %%
# Import csv library
import csv

# receive a filename or file path from a user: try to open movies.csv file
file_name = input("Enter a filename or file path: ")

# Open the file but that file does not exist however we handle file error so program is not stop or interrupt 
try:
    with open(file_name,encoding='UTF-8') as csv_file:
        print(f"{file_name} is now open for read")
    
except FileNotFoundError:
    print("File does not exist.")

# %%
# Import csv library
import csv

# receive a filename or file path from a user: try to open movies.csv file
file_name = input("Enter a filename or file path: ")

# Open the file but that file does not exist however we handle file error so program is not stop or interrupt 
try:
    with open(file_name,encoding='UTF-8') as csv_file:
        print(f"{file_name} is now open for read")
# print a more informative exception
except FileNotFoundError as e:
    print(f"File does not exist: {e}.")

# %% [markdown]
# Python Built-in Exceptions list: https://docs.python.org/3/library/exceptions.html

# %% [markdown]
# ## Ensuring Correct File Input with Exception Handling

# %% [markdown]
# When working with file input in a program, it's common for users to accidentally enter the wrong file name or path. To make your program more user-friendly and error-resistant, you can use exception handling to repeatedly prompt the user until a valid file is provided.
# - <font size =2> Why Use This Approach?</font>
#     - <font size=2>Prevents crashes: Avoids program errors when a file doesn't exist.</font>
#     - <font size=2>Improves user experience: Guides the user to correct mistake.</font>
#     - <font size=2> Ensures data availability: Guarantees that the program only proceeds when the data is successfully read.</font>
# - <font size=2>How It Works</font>
#     - <font size=2>Use a while loop to keep asking for the file name.</font>
#     - <font size=2>Use a try-except block to catch errors like FileNotFoundError.</font>
#     - <font size=2>Only break the loop when the file is successfully opened and read.</font>

# %%
# Import csv library
import csv

while True:
    # receive a filename or file path from a user: try to open movies.csv file
    file_name = input("Enter a filename or file path: ")

    # Open the file and handle file error so program is not stop or interrupt 
    try:
        with open(file_name,encoding='UTF-8') as csv_file:
            print(f"The {file_name} file has been successfully opened.")
            break # Exit the loop if file is read successfully
    except FileNotFoundError:
        print("File not found. Please try again.")

# %% [markdown]
# ## Read data from a csv file

# %% [markdown]
# - <font size="3">To read a CSV file in Python, we can use the <span style="color: blue;"> csv.reader()</span> function</font>
# - <font size="3"><b>Syntax:</b><br>
# &emsp;&emsp;&emsp;&emsp;<font size="3"> variable = <span style="color: blue;">csv.reader</span>(file_object)</font>
# - <font size="3">A CSV reader allows us to retrieve a row of data one at a time from the file</font>
# - <font size="3">When used with a loop, the reader object will return a list of values for each line in the file</font>

# %% [markdown]
# ### Example: open csv using open() function and read a csv file using csv reader

# %%
# Import csv library
import csv

while True:
    # receive a filename or file path from a user: try to open people.csv file
    file_name = input("Enter a filename or file path: ")

    # handle exceptions when opening a file and reading data from it
    try:
        # Open csv file and read data from a file
        with open(file_name,encoding='UTF-8') as csv_file:
            # Read a csv file
            csv_reader = csv.reader(csv_file)
        
            # Display a list of values for each line in the file
            for row in csv_reader:
                print(row)
            break # Exit the loop if file is read successfully
            
    except FileNotFoundError:
        print("File not found. Please try again.")
# Out:
# ['Title', ' Genre', ' Rating']
# ['x', ' y', ' 3']
# ['v', ' e', ' 5']

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> <br>
#     <ul>
#         <li>Often, when our file contains headings, we read in and store the headings separately</li>
#         <li>We can do this by using the python function <span style="color: blue;">next()</span>.  This function returns the next item of an iterator i.e., line in a file
# </li>
#         <li>Syntax: variable = <span style="color: blue;">next</span>(object)</li>
#     </ul>
# </div>

# %% [markdown]
# ### Example: reading headings from csv file

# %%
# Import csv library
import csv

while True:
    # receive a filename or file path from a user: try to open people.csv file
    file_name = input("Enter a filename or file path: ")

    # handle exceptions when opening a file and reading heading and data from it
    try:
        # Open csv file and read data from a file
        with open(file_name, encoding='UTF-8') as csv_file:
            csv_reader = csv.reader(csv_file)
        
            # read in and store the headers separately
            headers = next(csv_reader)
        
            # Display heading in csv file
            print(f"File headers: {headers}")
        
            # Display a list of values for each line
            for row in csv_reader:
                print(row)

            break # Exit the loop if file is read successfully
    except FileNotFoundError:
        print("File not found. Please try again.")
# Out:
# File headers: ['Title', ' Genre', ' Rating']
# ['x', ' y', ' 3']
# ['v', ' e', ' 5']

# %% [markdown]
# ## Reading Data from a CSV File and Storing It in a List
# When working with data stored in a CSV file, it's often inefficient to open and read the file every time you need to access the data. Instead, you can read the file once, store the data in a list (or another suitable data structure), and then use that list throughout your program.
# - <font size=2>Why Do This?</font>
#     - <font size=2>Efficiency: Reading from memory (a list) is much faster than reading from a file repeatedly.</font>
#     - <font size=2>
# Convenience: You can easily manipulate, filter, or analsze the data once it' loaded.</font>
#     - <font size=2>
# Cleaner Code: Your code becomes mo organised d and easier to maintai</font>n.

# %%
# Import csv library
import csv

#define empty list
data = []

while True:
    # receive a filename or file path from a user: try to open people.csv file
    file_name = input("Enter a filename or file path: ")

    # handle exceptions when opening a file and reading heading and data from it
    try:
        # Open csv file and read data from a file
        with open(file_name, encoding='UTF-8') as csv_file:
            csv_reader = csv.reader(csv_file)
        
            # read in and store the headers separately
            headers = next(csv_reader)

            # read and store the data in a list
            for row in csv_reader:
                data.append(row)
            break # Exit the loop if file is read successfully
    except FileNotFoundError:
        print("File not found. Please try again.")

# Now you can use `data` list anywhere in your program
# Display header
print(headers)

#Display data
for record in data:
    print(record)
# Out:
# ['Title', ' Genre', ' Rating']
# ['x', ' y', ' 3']
# ['v', ' e', ' 5']

# %% [markdown]
# ## Access individual element in header and data

# %%
# Import csv library
import csv

#define empty list
data = []

while True:
    # receive a filename or file path from a user: try to open people.csv file
    file_name = input("Enter a filename or file path: ")

    # handle exceptions when opening a file and reading heading and data from it
    try:
        # Open csv file and read data from a file
        with open(file_name, encoding='UTF-8') as csv_file:
            csv_reader = csv.reader(csv_file)
        
            # read in and store the headers separately
            headers = next(csv_reader)

             # read and store the data in a list
            for row in csv_reader:
                data.append(row)
            break # Exit the loop if file is read successfully
    except FileNotFoundError:
        print("File not found. Please try again.")


# Display individual header element
print(headers[0], headers[2])

#Display name and profession
for record in data:
    print(record[0],record[2])
# Out:
# Title  Rating
# x  3
# v  5

# %% [markdown]
# ## Write data to a csv file

# %% [markdown]
# ### write() function

# %% [markdown]
# - <font size=2>Python provides a built-in method called <span style="color: blue;">write()</span> that allows you to write text data directly into a file. </font>
# - <font size=2><span style="color: blue;">write()</span> adds text to the file exactly as given.</font>
# - <font size="2">Write data use commas to separate values.</font>
# - <font size=2>It does not automatically add a newline (\n), so you must include it if you want line breaks.</font>
# - <font size=2>If the file already exists in 'w' mode, its contents will be overwritten.</font>
# - <font size=2>If the file doesn’t exist, Python will create it.</font>

# %% [markdown]
# ### Exmaple: write()

# %%
# Choose the name of the file where you want to save the data.
file_name = input("Enter a filename or file path to write data: ")

# handle exceptions when opening a file for writing, then prompt the user for a value before writing it to the file
try:
    with open(file_name, 'w') as file:
        num_movies = int(input("How many movie would you like to enter?: "))
        #write a column name into a csv file
        file.write("Title, Genre, Rating\n")
        
        # get data from a user 
        for i in range(num_movies):
            title = input("Please enter the title of movie: ")
            genre = input("Please enter the movie genre: ")
            rating = input("Please enter the rating (1-5): ")
            
            # write user input in a format of csv - use commas to separate values
            file.write(f"{title}, {genre}, {rating}\n")
        
        print("Thanks! Your file has been written.")

except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ### writer(), writerow() and writerows() from csv module

# %% [markdown]
# Python’s csv module provides a simple way to write data into CSV (Comma-Separated Values) files. To do this:
# - <font size=2>you use the csv.writer() function to create a writer object that is linked to a file.</font>
# - <font size=2>then use either writerow() or writerows() to write data.</font>
#     - <font size=2>writerow writes a single row to the CSV file. Each row must be passed as a list (or other iterable).</font>
#     - <font size=2>writerows writes multiple rows in one call. You pass a <b>list of lists</b>, a table-like structure—similar to rows and columns in a spreadsheet or CSV file.</font>
# - <font size=2>Always open the file with newline='' to avoid extra blank lines on Windows.</font>

# %% [markdown]
# ### Example: writer(), writerow() and writerows()

# %%
import csv
# Choose the name of the file where you want to save the data.
file_name = input("Enter a filename or file path to write data: ")

# Open csv file to write data into a file
# the additional keyword argument newline='' to ensure that newlines are processed properly
try:
    with open(file_name,"w", newline='') as csv_file:
        # Create a writer object
        csv_writer = csv.writer(csv_file)
        headers = ["Account","Name","Balance"]
        data = [[100, 'Jones', 24.98],
                [200, 'Doe', 345.67],
                [300, 'White', 0.00],
                [400, 'Stone', -42.16],
                [500, 'Rich', 224.62]]
        # A writer object converts the data into a delimited string, then write into csv file
        csv_writer.writerow(headers)
        csv_writer.writerows(data) #The data variable is a list that stores the contents of the people.csv file we read in the previous step.
        
        print("Your file has been written.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Your file has been written.

# %%
file_name = input("Enter name: ")
# Open csv file to write data into a file
# the additional keyword argument newline='' to ensure that newlines are processed properly
try:
    with open(file_name,"w", newline='') as csv_file:
        # Create a writer object
        csv_writer = csv.writer(csv_file)
        
        # A writer object converts the data into a delimited string, then write into csv file
        csv_writer.writerow(headers)
        csv_writer.writerows(data) 
        #The data variable is a list that stores the contents of the people.csv file we read in the previous step.        
        print("Your file has been written.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Your file has been written.

# %%
import csv

file_name = "songs.csv"

try:
  with open(file_name, encoding='UTF-8') as file:
    csv_reader = csv.reader(file)
    headings = next(csv_reader)
    print(f"{headings[2]}\n")

    for values in csv_reader:
      print(values[2])
except FileNotFoundError:
    print("File does not exist.")
# Out:
# Category
#
# r&b
# pop
# rap
# pop
# pop
# rock
# electropop
# rap
# pop
# pop
# pop
# electropop
# pop

# %% [markdown]
# ---

# %% [markdown]
# ## Summary

# %% [markdown]
# - <font size="3">A file object is used to open a connection to a csv file for input or output</font>
# - <font size="3">Some useful functions: open, close, reader, write, writer, writerow, and writerows</font>
# - <font size="3">for loop treats an input file as a sequence of lines</font>
#     - <font size="3">on each pass through the loop, the loop’s variable is bound to a line of data read from the file</font>

# %% [markdown]
# ---
