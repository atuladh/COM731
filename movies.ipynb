# %%
import pandas as pd

file_path = "movies_dataset.csv”
# Load data from a csv to dataframe and set the first row to be column names
try:
     movie_df=pd.read_csv(file_path, header=0, encoding='utf-8’)
except FileNotFoundError as e1:
     print(f”File not found - {e1}”)
except Exception as e2:
     print(f”Exception - {e2}”)

# display a dataframe
movie_df
# Out:
#   Cell In[21], line 3
#     file_path = "\\movies_dataset.csv”
#                 ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
import os
print("Current working directory:", os.getcwd())
print("Files here:", os.listdir())
print("movies_dataset.csv" in os.listdir())
# Out:
# Current working directory: /Users/atuladhikari/Library/CloudStorage/OneDrive-Personal/Programming for Problem Solving/COM731
# Files here: ['movies_dataset.csv', 'week4.jpynb', 'movies.ipynb', 'Week 2.ipynb', 'Week4.ipynb', 'bank.csv', 'Week07.ipynb', 'songs.csv', 'Week03.ipynb', 'people.csv', '.DS_Store', 'Week 6.ipynb', 'LICENSE', 'Week2.ipynb', 'Untitled-1.ipynb', 'While_loops.ipynb', 'File_Operations_Notes.ipynb', 'Week_6.php', '8 - Multiple Linear Regression Model - Advertisement - Simple Version.ipynb', 'List.ipynb', 'att.csv', 'Week 1.ipynb', 'view2.ipynb', 'user_entries.csv', 'Week3.ipynb', 'Dictionary.ipynb', 'example_reallife.ipynb', 'README.md', 'Week4 2.ipynb', 'Basics_output.ipynb', '.gitignore', 'Basics_input.ipynb', 'decision.ipynb', 'decision 2.ipynb', 'files.ipynb', 'Input_and_Output_Notes.ipynb', 'view.php', 'Week3', 'week_3.ipynb', 'Week03 2.ipynb', 'view.ipynb', 'Week_6.ipynb', '.git', 'Untitled', 'movies.csv', 'week4.php', 'at.csv', 'students.csv', '.idea']
# ...
