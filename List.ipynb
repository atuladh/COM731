# %% [markdown]
# #Activity_markdown

# %%
#creating list of directions
directions = ["Move Forward", "Move Backward", "Turn Left", "Turm Right"]

#display the list
print(directions)
# Out:
# ['Move Forward', 'Move Backward', 'Turn Left', 'Turm Right']

# %% [markdown]
# #Activity:indexlist

# %%
#creating list of paths
paths = ["Move Forward", 10, "Move Backward", 5, "Move Left", 3, "Move Right", 1]

#displaying the path using index
print("Moving.....")
print(f"{paths[0]} for {paths[1]} steps")
print(f"{paths[2]} for {paths[3]} steps")
print(f"{paths[4]} for {paths[5]} steps")
print(f"{paths[6]} for {paths[7]} steps")
# Out:
# Moving.....
# Move Forward for 10 steps
# Move Backward for 5 steps
# Move Left for 3 steps
# Move Right for 1 steps

# %% [markdown]
# #paths using index with loops

# %%
#path
paths = ["Move Forward", 10, "Move Backward", 5, "Move Left", 3, "Move Right", 1]
#displaying the path using index with loop
print("Moving.....")

for index in range(0, len(paths), 2):
    print(f"{paths[index]} for {paths[index+1]} steps")
# Out:
# Moving.....
# Move Forward for 10 steps
# Move Backward for 5 steps
# Move Left for 3 steps
# Move Right for 1 steps
